# %% [markdown]
# #### Задания по теме «Производные функций нескольких переменных».
#
# 1. Найти область определения функции
#
# $$z =  \sqrt{1 - x^3} + \ln \left(y^2 - 1\right)$$
#
# $$1-x^3 \geq 0 \\
# 1 \geq x^3 \\
# x \leq 1;$$
#
# $$y^2-1 > 0 \\
# y^2 > 1 \\
# y_1 > 1, y_2 < -1$$
#
#
# $${(x, y) \in R^2 : (y>1  \&  x<=1) \parallel (y<-1  \&  x<=1)}$$

# %% [markdown]
# 2. Найти производные 1-го порядка функции.
#
# $$z = \left(1+\frac{\ln\left(x\right)} {\ln\left(y\right)}\right) ^3$$
#
# $${ z = (1+\frac{ln(x)}{ln(y)})^3 }$$
#
# $${ \frac{d}{dx}f(x,y)= \frac{3(\frac{ln(x)}{ln(y)}+1)^2}{x*ln(y)} }$$
#
# $${ \frac{d}{dy}f(x,y)= \frac{3(\frac{ln(x)}{ln(y)}+1)^2*ln(x)}{y*ln(y)^2} }$$
#
# $${ \frac{dy}{dx} = y* \frac{ln(y)}{x*ln(x)} } $$

# %% [markdown]
# 3. Найти полный дифференциал функции в точке (1;1).
# $${ \sqrt{2xy+cos\frac{x}{y}} } $$
#
# $${ (\frac{y-\frac{sin(\frac{x}{y})}{2y}}{\sqrt{2xy+cos(\frac{x}{y})}})dx + (\frac{x+\frac{xsin(\frac{x}{y})}{2y^2}}{\sqrt{2xy+cos(\frac{x}{y})}})dy }$$
#
# $${ dz(1;1) = (\frac{2-sin(1)}{2\sqrt{2+cos(1)}})dx + \frac{2+sin(1)}{2\sqrt{2+cos(1)}} dy } $$
#
# $${ dz(1;1) = (0.364dx+0.891dy) }$$

# %% [markdown]
#  4. Исследовать на экстремум функцию
# $$z = x^2 +xy + y^2 - 6x -9y \\
# \frac{\partial z}{\partial x} = 2x+y-6\\
# \frac{\partial z}{\partial y} = x+2y-9 \\
# \begin{equation*}
#  \begin{cases}
#    2x+y-6 = 0
#    \\
#    x+2y-9 = 0
#  \end{cases}
# \end{equation*}
# \\
# x = -2y+9 \\
# 2(-2y+9)-6+y = 0 \\
# y = 4 \\
# x = 1 \\
# \Delta \begin{bmatrix}
# z_{xx}^{\prime\prime} & z_{xy}^{\prime\prime}\\
# z_{yx}^{\prime\prime} & z_{yy}^{\prime\prime}
# \end{bmatrix} = \Delta \begin{bmatrix}
# 2 & 1\\
# 1 & 2
# \end{bmatrix} = 3 > 0
# $$
#
#
# Минимум в точке (1; 4;)

# %% [markdown]
# #### Задания из коллаба.

# %% [markdown]
# 1. Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# $$U=x^3+3xy^2+z^2-39x-36y+2z+26$$
#
# Первого порядка:
#
# $$U'x=3x^2+3y^2-39$$
# $$U'y=6xy-36$$
# $$U'z=2z+2$$
#
# Второго порядка:
#
# От $x$:
# $$U''xx=6x$$
# $$U''xy=6y$$
# $$U''xz=0$$
#
# От $y$:
# $$U''yx=6y$$
# $$U''yy=6x$$
# $$U''yz=0$$
#
# От $z$:
# $$U''zx=0$$
# $$U''zy=0$$
# $$U''zz=2$$

# %% [markdown]
# 2. Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# $$U=\frac{256}{x}+\frac{x^2}{y}+\frac{y^2}{z}+z^2$$
#
#
# Первого порядка:
#
# $$U'x=-\frac{256}{x^2}+\frac{2x}{y}$$
# $$U'y=-\frac{x^2}{y^2}+\frac{2y}{z}$$
# $$U'z=-\frac{y^2}{z^2}+2z$$
#
# Второго порядка:
#
# От $x$:
# $$U''xx=\frac{512}{x^3}+\frac{2}{y}$$
# $$U''xy=-\frac{2x}{y^2}$$
# $$U''xz=0$$
#
# От $y$:
# $$U''yx=-\frac{2x}{y^2}$$
# $$U''yy=\frac{2x^2}{y^3}+\frac{2}{z}$$
# $$U''yz=-\frac{2y}{z^2}$$
#
# От $z$:
# $$U''zx=0$$
# $$U''zy=-\frac{2y}{z^2}$$
# $$U''zz=\frac{2y^2}{z^3}+2$$

# %% [markdown]
# 6. Исследовать на экстремум функцию:
#
# $$U=x^2y+\frac{1}{3}y^3+2x^2+3y^2-1$$
#
# Находим частные производные, приравниваем их к нулю и находим стационарные точки:
#
# $$\begin{cases}
#    U'_{x}=2xy+4x=0 \\
#    U'_{y}=x^2+y^2+6y=0
#  \end{cases}\,\,\,\,\,\Rightarrow\,\,\,\,\,
#  \begin{cases}
#    \left[
#   \begin{gathered}
#      x=0\\
#      y=-2
#   \end{gathered}
# \right. \\
#    x^2+y^2+6y=0
#  \end{cases}\,\,\,\,\,\Rightarrow$$
#
# $$\Rightarrow\,\,\,\,\,\left[
#   \begin{gathered}
#      \begin{cases}
#    x=0 \\
#   y^2+6y=0
#  \end{cases}\\
#      \begin{cases}
#    y=-2 \\
#    x^2=8
#  \end{cases}
#   \end{gathered}
# \right.\,\,\,\,\,\Rightarrow\,\,\,\,\,
# \begin{gathered}
# (0,0)\\
# (0,-6)\\
# (2\sqrt2,-2)\\
# (-2\sqrt2,-2)
# \end{gathered}$$
#
# Находим вторые производные и составляем матрицу Гёссе в общем виде:
#
# $$U''_{xx}=2y+4$$
# $$U''_{xy}=U''_{yx}=2x$$
# $$U''_{yy}=2y+6$$
#
# $$\begin{pmatrix}
# 2y+4 & 2x\\
# 2x & 2y+6\\
# \end{pmatrix}$$
#
# Вычисляем главные миноры:
#
# $$\Delta_{1}=U''_{xx}=2y+4$$
#
# $$\Delta_{2}=\begin{vmatrix}
# U''_{xx} & U''_{xy}\\
# U''_{yx} & U''_{yy}\\
# \end{vmatrix}=U''_{xx}\cdot U''_{yy}-(U''_{xy})^2=4y^2+20y+24-4x^2$$
#
# Проверяем знаки миноров для каждой точки:
#
# Для точки $(0,0)$
#
# $$\Delta_{1}=2y+4=4>0$$
#
# $$\Delta_{2}=4y^2+20y+24-4x^2=24>0$$
#
# $(0,0)$ - точка минимума
#
# Для точки $(0,-6)$
#
# $$\Delta_{1}=2y+4=-8<0$$
#
# $$\Delta_{2}=4y^2+20y+24-4x^2=48>0$$
#
# $(0,-6)$ - точка максимума
#
# Для точки $(\pm2\sqrt2,-2)$
#
# $$\Delta_{1}=2y+4=0$$
